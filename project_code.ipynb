# %% [markdown]
# # Multiclass  classification on Stanford Dog Breeds dataset

# %% [markdown]
# ### 1. define the problem and assemble the dataset
#
# In this project, we will tackle a multi-class classification problem using the Stanford Dogs dataset. This dataset contains images of 120 breeds of dogs from around the world, where we have unbalanced number of image data for each class. However, the dataset are not extremely imbalanced, the number of images per class range between 150 to 200. There are 20580 images of different sizes in total. This dataset has been built using images and annotation from ImageNet for the task of fine-grained image categorization. It was originally collected for fine-grain image categorization, a challenging problem as certain dog breeds have near identical features or differ in color and age.

# %% [markdown]
# ### 2. Choose a measure of success
#
# My model will take an accuracy score and as a measure of success.

# %% [markdown]
# ### 3. Decide on an evaluation protocol
#
# We will use a hold out validation method to split the training and validation set. Since we have our dataset directly downloaded from kaggle, we considered that it would be easoer for us to split our data directly within the image directory. We are using a 7:1.5:1.5 split for the training, testing and validation split.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
from keras import optimizers
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from keras import layers 
from keras import models
import cv2 # OpenCV module that handles computer vision methods

# %matplotlib inline

# %%
# libraries for a CNN
import tensorflow as tf
from tensorflow import keras


from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense

# %%
from numpy import expand_dims
#from keras.preprocessing.image import load_img
#from keras.preprocessing.image import img_to_array
#from keras import backend as K
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model
import imageio
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model

# %%
import os, shutil

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/527_Final_project/')
path = os.getcwd()
print(path)
# Out:
# /content/drive/My Drive/527_Final_project

# %%
ANNOTATION_DIR = '/content/drive/My Drive/527_Final_project/labels/' 
IMAGES_DIR ='/content/drive/My Drive/527_Final_project/Images/'

# %%
base_dir = '/content/drive/My Drive/527_Final_project/30_Classes_Separated_Data'

# os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train') 
# os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation') 
# os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test') 
# os.mkdir(test_dir)

# %%
import glob
breed_list = glob.glob(IMAGES_DIR+'n*')
print("num of breeds total:", len(breed_list))
# Out:
# num of breeds total: 120

# %%
print(breed_list[0][53:])
# Out:
# 97658-silky_terrier

# %%
for i in range(30):
    train_class_dir = os.path.join(train_dir, breed_list[i][53:]) 
    #os.mkdir(train_class_dir)
    
    test_class_dir = os.path.join(test_dir, breed_list[i][53:]) 
    #os.mkdir(test_class_dir)
    
    val_class_dir = os.path.join(validation_dir, breed_list[i][53:]) 
    #os.mkdir(val_class_dir)

# %%
for i in range(30):
    img_dir = breed_list[i]
    listing = glob.glob(img_dir+'/*.jpg')
    
    num_train = int(len(listing)*0.7)
    reminder_images = len(listing)-num_train
    num_test = int(reminder_images*0.5)
    reminder = reminder_images - num_test
    num_val = int(reminder)
    
    print(str(len(listing)), str(num_train+num_test+num_val))
    
    for j in range(0,num_train):
        src = listing[j]
        train_class_dir = os.path.join(train_dir, breed_list[i][53:])     
        dst = os.path.join(train_class_dir,os.path.basename(listing[j])) 
        shutil.copyfile(src, dst)
    
    for j in range(num_train,num_test+num_train):
        src = listing[j]
        test_class_dir = os.path.join(test_dir, breed_list[i][53:])     
        dst = os.path.join(test_class_dir,os.path.basename(listing[j])) 
        shutil.copyfile(src, dst)
    
    for j in range(num_train+num_test,num_train+num_test+num_val):
        src = listing[j]
        val_class_dir = os.path.join(validation_dir, breed_list[i][53:])     
        dst = os.path.join(val_class_dir,os.path.basename(listing[j])) 
        shutil.copyfile(src, dst)
# Out:
# 183 183
# 157 157
# 200 200
# 167 167
# 151 151
# 181 181
# 232 232
# 159 159
# 154 154
# 188 188
# 157 157
# 185 185
# 150 150
# 150 150
# 154 154
# 155 155
# 159 159
# 154 154
# 202 202
# 178 178
# 150 150
# 155 155
# 150 150
# 157 157
# 149 149
# 150 150
# 150 150
# 192 192
# 164 164
# 152 152

# %% [markdown]
# We would like to split the images into a train, test and validation dataset, where 70% of the data will become the training data, 15% will be the validation data and 15% will be our test data.

# %%
# insight on how many images are stored in each class
sum = 0
for i in range(120):
    img_dir = breed_list[i]
    listing = glob.glob(img_dir+'/*.jpg')
    print("class", i+1, "contains", len(listing), "images")
    sum += len(listing)
print(sum)
# Out:
# class 1 contains 183 images
# class 2 contains 157 images
# class 3 contains 200 images
# class 4 contains 167 images
# class 5 contains 151 images
# class 6 contains 181 images
# class 7 contains 232 images
# class 8 contains 159 images
# class 9 contains 154 images
# class 10 contains 188 images
# class 11 contains 157 images
# class 12 contains 185 images
# class 13 contains 150 images
# class 14 contains 150 images
# class 15 contains 154 images
# class 16 contains 155 images
# class 17 contains 159 images
# class 18 contains 154 images
# class 19 contains 202 images
# class 20 contains 178 images
# class 21 contains 150 images
# class 22 contains 155 images
# class 23 contains 150 images
# class 24 contains 157 images
# class 25 contains 149 images
# class 26 contains 150 images
# class 27 contains 150 images
# class 28 contains 192 images
# class 29 contains 164 images
# class 30 contains 152 images
# class 31 contains 169 images
# class 32 contains 185 images
# class 33 contains 179 images
# class 34 contains 252 images
# class 35 contains 172 images
# class 36 contains 152 images
# class 37 contains 156 images
# class 38 contains 180 images
# class 39 contains 152 images
# class 40 contains 172 images
# class 41 contains 197 images
# class 42 contains 152 images
# class 43 contains 175 images
# class 44 contains 148 images
# class 45 contains 168 images
# class 46 contains 218 images
# class 47 contains 188 images
# class 48 contains 150 images
# class 49 contains 169 images
# class 50 contains 150 images
# class 51 contains 196 images
# class 52 contains 171 images
# class 53 contains 152 images
# class 54 contains 202 images
# class 55 contains 155 images
# class 56 contains 206 images
# class 57 contains 218 images
# class 58 contains 196 images
# class 59 contains 155 images
# class 60 contains 153 images
# class 61 contains 154 images
# class 62 contains 196 images
# class 63 contains 160 images
# class 64 contains 184 images
# class 65 contains 200 images
# class 66 contains 164 images
# class 67 contains 169 images
# class 68 contains 151 images
# class 69 contains 172 images
# class 70 contains 153 images
# class 71 contains 214 images
# class 72 contains 152 images
# class 73 contains 151 images
# class 74 contains 171 images
# class 75 contains 187 images
# class 76 contains 151 images
# class 77 contains 182 images
# class 78 contains 161 images
# class 79 contains 150 images
# class 80 contains 158 images
# class 81 contains 196 images
# class 82 contains 152 images
# class 83 contains 186 images
# class 84 contains 195 images
# class 85 contains 153 images
# class 86 contains 157 images
# class 87 contains 153 images
# class 88 contains 197 images
# class 89 contains 172 images
# class 90 contains 169 images
# class 91 contains 218 images
# class 92 contains 180 images
# class 93 contains 195 images
# class 94 contains 187 images
# class 95 contains 209 images
# class 96 contains 182 images
# class 97 contains 155 images
# class 98 contains 156 images
# class 99 contains 202 images
# class 100 contains 158 images
# class 101 contains 239 images
# class 102 contains 182 images
# class 103 contains 156 images
# class 104 contains 150 images
# class 105 contains 213 images
# class 106 contains 150 images
# class 107 contains 151 images
# class 108 contains 159 images
# class 109 contains 151 images
# class 110 contains 152 images
# class 111 contains 159 images
# class 112 contains 150 images
# class 113 contains 164 images
# class 114 contains 151 images
# class 115 contains 159 images
# class 116 contains 156 images
# class 117 contains 153 images
# class 118 contains 150 images
# class 119 contains 219 images
# class 120 contains 210 images
# 20599

# %% [markdown]
# We have a somewhat unbalanced dataset, but it is not extremely unbalanced. The number of images we have for each class range between 150 to 200.

# %%
# visualize breeds
filtered_breeds = [breed.split('-',1)[-1] for breed in breed_list] 
filtered_breeds[:120]
# Out:
# ['silky_terrier',
#  'wire-haired_fox_terrier',
#  'Saluki',
#  'Chesapeake_Bay_retriever',
#  'borzoi',
#  'Pembroke',
#  'Scottish_deerhound',
#  'cocker_spaniel',
#  'schipperke',
#  'Ibizan_hound',
#  'English_foxhound',
#  'Japanese_spaniel',
#  'golden_retriever',
#  'Eskimo_dog',
#  'komondor',
#  'Staffordshire_bullterrier',
#  'standard_poodle',
#  'miniature_schnauzer',
#  'Sealyham_terrier',
#  'malamute',
#  'Doberman',
#  'Mexican_hairless',
#  'dhole',
#  'giant_schnauzer',
#  'Pekinese',
#  'Bouvier_des_Flandres',
#  'malinois',
#  'Siberian_husky',
#  'standard_schnauzer',
#  'German_shepherd',
#  'Irish_terrier',
#  'Norwich_terrier',
#  'Kerry_blue_terrier',
#  'Maltese_dog',
#  'Norfolk_terrier',
#  'Tibetan_mastiff',
#  'bull_mastiff',
#  'Saint_Bernard',
#  'briard',
#  'Border_terrier',
#  'Lakeland_terrier',
#  'Chihuahua',
#  'basset',
#  'redbone',
#  'Greater_Swiss_Mountain_dog',
#  'Irish_wolfhound',
#  'Blenheim_spaniel',
#  'Border_collie',
#  'West_Highland_white_terrier',
#  'kuvasz',
#  'papillon',
#  'bluetick',
#  'German_short-haired_pointer',
#  'EntleBucher',
#  'Cardigan',
#  'Tibetan_terrier',
#  'Bernese_mountain_dog',
#  'Norwegian_elkhound',
#  'miniature_poodle',
#  'Gordon_setter',
#  'vizsla',
#  'chow',
#  'Weimaraner',
#  'miniature_pinscher',
#  'pug',
#  'American_Staffordshire_terrier',
#  'Old_English_sheepdog',
#  'boxer',
#  'Rhodesian_ridgeback',
#  'kelpie',
#  'Shih-Tzu',
#  'flat-coated_retriever',
#  'Sussex_spaniel',
#  'Labrador_retriever',
#  'whippet',
#  'otterhound',
#  'Italian_greyhound',
#  'English_setter',
#  'affenpinscher',
#  'Scotch_terrier',
#  'Australian_terrier',
#  'Rottweiler',
#  'Lhasa',
#  'Newfoundland',
#  'collie',
#  'Shetland_sheepdog',
#  'Walker_hound',
#  'cairn',
#  'toy_terrier',
#  'African_hunting_dog',
#  'Samoyed',
#  'Dandie_Dinmont',
#  'beagle',
#  'bloodhound',
#  'basenji',
#  'Bedlington_terrier',
#  'Irish_setter',
#  'Great_Dane',
#  'Airedale',
#  'keeshond',
#  'Afghan_hound',
#  'Boston_bull',
#  'dingo',
#  'Welsh_springer_spaniel',
#  'Great_Pyrenees',
#  'clumber',
#  'Appenzeller',
#  'English_springer',
#  'toy_poodle',
#  'Brittany_spaniel',
#  'black-and-tan_coonhound',
#  'groenendael',
#  'Yorkshire_terrier',
#  'curly-coated_retriever',
#  'French_bulldog',
#  'soft-coated_wheaten_terrier',
#  'Brabancon_griffon',
#  'Irish_water_spaniel',
#  'Pomeranian',
#  'Leonberg']

# %%
print(breed_list[0][53:])
# Out:
# 97658-silky_terrier

# %%
i = 0
for breed in breed_list:
    train_class_dir = os.path.join(train_dir, breed_list[i][53:]) 
    #os.mkdir(train_class_dir)
    
    test_class_dir = os.path.join(test_dir, breed_list[i][53:]) 
    #os.mkdir(test_class_dir)
    
    val_class_dir = os.path.join(validation_dir, breed_list[i][53:]) 
    #os.mkdir(val_class_dir)
    
    i = i+1

# %%
print(breed_list[0])
# Out:
# /content/drive/My Drive/527_Final_project/Images/n02097658-silky_terrier

# %%
#fnames = ['cat.{}.jpg'.format(i) for i in range(1000)] 
#for fname in fnames:
 #   src = os.path.join(original_dataset_dir, fname) 
  #  dst = os.path.join(train_cats_dir, fname) 
   # shutil.copyfile(src, dst)
    
for i in range(30):
    img_dir = breed_list[i]
    listing = glob.glob(img_dir+'/*.jpg')
    
    num_train = int(len(listing)*0.7)
    reminder_images = len(listing)-num_train
    num_test = int(reminder_images*0.5)
    reminder = reminder_images - num_test
    num_val = int(reminder)
    
    print(str(len(listing)), str(num_train+num_test+num_val))
    
    for j in range(0,num_train):
        src = listing[j]
        train_class_dir = os.path.join(train_dir, breed_list[i][53:])     
        dst = os.path.join(train_class_dir,os.path.basename(listing[j])) 
        shutil.copyfile(src, dst)
    
    for j in range(0,num_test):
        src = listing[j]
        test_class_dir = os.path.join(test_dir, breed_list[i][53:])     
        dst = os.path.join(test_class_dir,os.path.basename(listing[j])) 
        shutil.copyfile(src, dst)
    
    for j in range(0,num_val):
        src = listing[j]
        val_class_dir = os.path.join(validation_dir, breed_list[i][53:])     
        dst = os.path.join(val_class_dir,os.path.basename(listing[j])) 
        shutil.copyfile(src, dst)
# Out:
# 183 183
# 157 157
# 200 200
# 167 167
# 151 151
# 181 181
# 232 232
# 159 159
# 154 154
# 188 188
# 157 157
# 185 185
# 150 150
# 150 150
# 154 154
# 155 155
# 159 159
# 154 154
# 202 202
# 178 178
# 150 150
# 155 155
# 150 150
# 157 157
# 149 149
# 150 150
# 150 150
# 192 192
# 164 164
# 152 152

# %%
# sanity check
print('total training breeds images:', len(os.listdir(train_class_dir)))
print('total testing breeds images:', len(os.listdir(test_class_dir)))
print('total validation breeds images:', len(os.listdir(val_class_dir)))
# Out:
# total training breeds images: 106
# total testing breeds images: 46
# total validation breeds images: 46

# %%
def show_dir_images(breed, n_to_show):
    plt.figure(figsize=(16,16))
    img_dir = "/content/drive/My Drive/527_Final_project/Images/{}/".format(breed)
    images = os.listdir(img_dir)[:n_to_show]
    for i in range(n_to_show):
        img = cv2.imread(img_dir + images[i])
        plt.subplot(n_to_show/4+1, 4, i+1)
        plt.imshow(img)
        plt.axis('off')



print(breed_list[11])
#show_dir_images(breed_list[0], 4)
# Out:
# /content/drive/My Drive/527_Final_project/Images/n02085782-Japanese_spaniel

# %% [markdown]
# ### 4. prepare the data

# %%
image_path = '/content/drive/My Drive/527_Final_project/Images/'
train_dir = '/content/drive/My Drive/527_Final_project/30_Classes_Separated_Data/train'
test_dir = '/content/drive/My Drive/527_Final_project/30_Classes_Separated_Data/test'
validation_dir = '/content/drive/My Drive/527_Final_project/30_Classes_Separated_Data/validation'

num_of_categories = 30
image_size = 192
batch_size = 16

# %% [markdown]
# We will use the module built inside Keras with image processing helper tools -- `keras.preprocessing.image`. It contains the class `ImageDataGenerator` which allows to quickly set up Python generators that can automatically turn image files on disk into batches of pre-processed tensors. This is what we will use here.

# %%
def image_preprocess(image):
    image = tf.image.per_image_standardization(image)
    return image

def image_datagen_load():
    train_datagen = keras.preprocessing.image.ImageDataGenerator(
        #rotation_range=30, 
        #width_shift_range=0.2, 
        #zca_whitening=True, 
        #shear_range=0.2,
        #height_shift_range=0.2, 
        #brightness_range=[0.9,1.1], 
        #zoom_range=0.1, 
        #fill_mode='constant', 
        #cval=0.0, 
        #horizontal_flip=True, 
        # All images will be rescaled by 1/255.
        rescale=1/255., 
        preprocessing_function=None,
        dtype='float32')
    
    test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)


    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size,
        shuffle=True)

    validation_generator = test_datagen.flow_from_directory(
        validation_dir, 
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size, 
        shuffle=False)

    return train_generator, validation_generator

# %%
train_generator, validation_generator = image_datagen_load()
# Out:
# Found 3476 images belonging to 30 classes.
# Found 1526 images belonging to 30 classes.

# %%
# sanity check
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
    
for data_batch, labels_batch in validation_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (16, 192, 192, 3)
# labels batch shape: (16, 120)
# data batch shape: (16, 192, 192, 3)
# labels batch shape: (16, 120)

# %% [markdown]
# Let's take a look at the output of one of these generators: it yields batches of RGB images (shape `(16, 192, 192, 3)`) and
#     labels of shape `(16,120)`. 16 is the number of samples in each batch (the batch size), and 120 corresponds to 120 classes.

# %% [markdown]
# ### 5. Develop a model that is better than the baseline
#
# Since we have 120 classes, the baseline accuracy should be 0.012. Since we are just building a very simple model, we just want to assure that this model converges and the accuracy is greater than 0.012. Thus, we will only identify one convolution layer and one maxpooling layer. Also, we will only add one hidden layer in my dense neural network structure.

# %%
# train from baseline
from keras import layers 
from keras import models

# build the network (convolution layer)
model = models.Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(192, 192, 3))) 
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu')) 
model.add(layers.MaxPooling2D((2, 2)))

'''
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
'''

# build the network (dense layer)
model.add(layers.Flatten()) 
#model.add(layers.Dense(256, activation='relu')) 
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(120, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 190, 190, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 95, 95, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 93, 93, 64)        9280
#
#  max_pooling2d_1 (MaxPooling  (None, 46, 46, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 64)                8667200
#
#  dense_1 (Dense)             (None, 120)               7800
#
# =================================================================
# Total params: 8,684,728
# Trainable params: 8,684,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model for training
# use sparse_categorical_crossentropy for integer data
# use an rmsprop optimizor the minimize the sparse_crossentropy
# use 'accuracy' as the measure of success

model.compile(loss='categorical_crossentropy',
              ## optimizer=Adam(lr=0.001, decay=0, beta_1=0.9, beta_2=0.999),
              optimizer = 'rmsprop',
              metrics=['accuracy'])

# %%
#batch_size = 20
history = model.fit(
      train_generator,
      steps_per_epoch=14458//batch_size,
      epochs=10,
      validation_data=validation_generator,
      validation_steps=50)

# %%
import pickle
with open('cifar-100 trainHistoryDict.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# save the simple model for later convenience
model.save('dogs1.h5')

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss)+1)
plt.figure(figsize = (12, 5))
# visualize history: loss

plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('Loss')
plt.xlabel('Num of epoch')
plt.legend()

# visualize history: accuracy
plt.subplot(1, 2, 2)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Num of epoch')
plt.legend()

plt.show()

# %% [markdown]
# Based on the results of accuracy test, we have just defeated the baseline. However, from the plot, we can also see that we have both underfit and overfit problems. This is understandable given we have few layers and little parameters to learn from during the training process. For the next section, we will train the model using 3 different pretrained neural network to see which one would give us a better result.

# %% [markdown]
# # Transfer Learning - Feature extraction

# %%
from tensorflow.keras.applications import EfficientNetB0

conv_base = EfficientNetB0(weights='imagenet',
                  include_top=False,
                  input_shape=(192, 192, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 192, 192, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 192, 192, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 193, 193, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 96, 96, 32)   864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 96, 96, 32)   128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 96, 96, 32)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 96, 96, 32)   288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 96, 96, 32)   128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 96, 96, 32)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 96, 96, 32)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 96, 96, 16)   512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 96, 96, 16)   64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 96, 96, 96)   1536        block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 96, 96, 96)   384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 96, 96, 96)   0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 97, 97, 96)   0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 48, 48, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 48, 48, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 48, 48, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 48, 48, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 48, 48, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 48, 48, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 48, 48, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 48, 48, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 48, 48, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 48, 48, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 48, 48, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 48, 48, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 48, 48, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 48, 48, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 48, 48, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 48, 48, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 48, 48, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 48, 48, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 48, 48, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 48, 48, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 51, 51, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 24, 24, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 24, 24, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 24, 24, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 24, 24, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 24, 24, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 24, 24, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 24, 24, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 24, 24, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 24, 24, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 24, 24, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 24, 24, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 24, 24, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 24, 24, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 24, 24, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 24, 24, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 24, 24, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 24, 24, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 24, 24, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 24, 24, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 24, 24, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 25, 25, 240)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 12, 12, 240)  2160        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 12, 12, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 12, 12, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 12, 12, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 12, 12, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 12, 12, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 12, 12, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 12, 12, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 12, 12, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 12, 12, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 12, 12, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 12, 12, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 12, 12, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 12, 12, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 12, 12, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 12, 12, 80)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 12, 12, 80)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 12, 12, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 12, 12, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 12, 12, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 12, 12, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 12, 12, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 12, 12, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 12, 12, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 12, 12, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 12, 12, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 12, 12, 80)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 12, 12, 80)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 12, 12, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 12, 12, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 12, 12, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 12, 12, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 12, 12, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 12, 12, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 12, 12, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 12, 12, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 12, 12, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 12, 12, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 12, 12, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 12, 12, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 12, 12, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 12, 12, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 12, 12, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 12, 12, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 12, 12, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 12, 12, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 12, 12, 112)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 12, 12, 112)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 12, 12, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 12, 12, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 12, 12, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 12, 12, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 12, 12, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 12, 12, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 12, 12, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 12, 12, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 12, 12, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 12, 12, 112)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 12, 12, 112)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv (Conv2D)    (None, 12, 12, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 12, 12, 672)  2688        block6a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 12, 12, 672)  0           block6a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 15, 15, 672)  0           block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv (DepthwiseConv2D (None, 6, 6, 672)    16800       block6a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 6, 6, 672)    2688        block6a_dwconv[0][0]
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 6, 6, 672)    0           block6a_bn[0][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[0][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6a_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block6a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6a_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block6a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 6, 6, 672)    0           block6a_activation[0][0]
#                                                                  block6a_se_expand[0][0]
# __________________________________________________________________________________________________
# block6a_project_conv (Conv2D)   (None, 6, 6, 192)    129024      block6a_se_excite[0][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 6, 6, 192)    768         block6a_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_conv (Conv2D)    (None, 6, 6, 1152)   221184      block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 6, 6, 1152)   4608        block6b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 6, 6, 1152)   0           block6b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6b_dwconv (DepthwiseConv2D (None, 6, 6, 1152)   28800       block6b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 6, 6, 1152)   4608        block6b_dwconv[0][0]
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 6, 6, 1152)   0           block6b_bn[0][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[0][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6b_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6b_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 6, 6, 1152)   0           block6b_activation[0][0]
#                                                                  block6b_se_expand[0][0]
# __________________________________________________________________________________________________
# block6b_project_conv (Conv2D)   (None, 6, 6, 192)    221184      block6b_se_excite[0][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 6, 6, 192)    768         block6b_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 6, 6, 192)    0           block6b_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 6, 6, 192)    0           block6b_drop[0][0]
#                                                                  block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_expand_conv (Conv2D)    (None, 6, 6, 1152)   221184      block6b_add[0][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 6, 6, 1152)   4608        block6c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 6, 6, 1152)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 6, 6, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 6, 6, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 6, 6, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 6, 6, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 6, 6, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 6, 6, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 6, 6, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 6, 6, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 6, 6, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 6, 6, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 6, 6, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 6, 6, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 6, 6, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 6, 6, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 6, 6, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 6, 6, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 6, 6, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 6, 6, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 6, 6, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 6, 6, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 6, 6, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 6, 6, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 6, 6, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 6, 6, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 6, 6, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 6, 6, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 6, 6, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 6, 6, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 6, 6, 1280)   409600      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 6, 6, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 6, 6, 1280)   0           top_bn[0][0]
# ==================================================================================================
# Total params: 4,049,571
# Trainable params: 4,007,548
# Non-trainable params: 42,023
# __________________________________________________________________________________________________

# %%
model = models.Sequential()
conv_base.trainable = False;
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu', input_dim=6 * 6 * 1280))
model.add(layers.BatchNormalization())
#model.add(layers.Dropout(0.3)) 
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5)) 
model.add(layers.Dense(30, activation='softmax'))

# %%
from keras.preprocessing.image import ImageDataGenerator


train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size,
        shuffle=True)

validation_generator = test_datagen.flow_from_directory(
        validation_dir, 
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size, 
        shuffle=False)
# Out:
# Found 3640 images belonging to 30 classes.
# Found 796 images belonging to 30 classes.

# %%
model.compile(loss='categorical_crossentropy',
              #optimizer=Adam(lr=0.001, decay=0, beta_1=0.9, beta_2=0.999),
              optimizer = 'rmsprop',
              metrics=['accuracy'])

batch_size = 20
history = model.fit(
      train_generator,
      steps_per_epoch=3640//20,
      epochs=50,
      validation_data=validation_generator,
      validation_steps=50,
      verbose=2)
# Out:
# Epoch 1/50

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# #VGG

# %%
image_path = '/content/drive/My Drive/CSC 375 Final Project/Images/'
train_dir = '/content/drive/My Drive/CSC 375 Final Project/30_Classes_Separated_Data/train'
test_dir = '/content/drive/My Drive/CSC 375 Final Project/30_Classes_Separated_Data/test'
validation_dir = '/content/drive/My Drive/CSC 375 Final Project/30_Classes_Separated_Data/validation'

num_of_categories = 30
image_size = 192
batch_size = 16

# %%
from keras.applications import VGG16

conv_base = VGG16(weights='imagenet', include_top=False,
                input_shape=(192, 192, 3))


conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 192, 192, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 192, 192, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 192, 192, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 96, 96, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 96, 96, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 96, 96, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 48, 48, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 48, 48, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 24, 24, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 24, 24, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_base.trainable = False

# %%
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu', input_dim=6 * 6 * 512))
model.add(layers.BatchNormalization())
#model.add(layers.Dropout(0.3)) 
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5)) 
model.add(layers.Dense(30, activation='softmax'))

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)
    

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size,
        shuffle=True)

validation_generator = test_datagen.flow_from_directory(
        validation_dir, 
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size, 
        shuffle=False)

model.compile(loss='categorical_crossentropy',
              #optimizer=Adam(lr=0.001, decay=0, beta_1=0.9, beta_2=0.999),
              optimizer = 'rmsprop',
              metrics=['accuracy'])
# Out:
# Found 3640 images belonging to 30 classes.
# Found 796 images belonging to 30 classes.

# %%
history = model.fit(train_generator,
                                steps_per_epoch=50,
                                epochs=50, 
                                validation_data=validation_generator, 
                                validation_steps=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 778s 16s/step - loss: 4.2646 - accuracy: 0.0712 - val_loss: 6.7713 - val_accuracy: 0.0741
# Epoch 2/50
# 50/50 [==============================] - 289s 6s/step - loss: 3.1715 - accuracy: 0.2020 - val_loss: 4.7704 - val_accuracy: 0.1143
# Epoch 3/50
# 50/50 [==============================] - 223s 4s/step - loss: 2.7485 - accuracy: 0.2688 - val_loss: 3.0243 - val_accuracy: 0.2475
# Epoch 4/50
# 50/50 [==============================] - 188s 4s/step - loss: 2.3758 - accuracy: 0.3462 - val_loss: 2.5532 - val_accuracy: 0.3216
# Epoch 5/50
# 50/50 [==============================] - 141s 3s/step - loss: 2.2516 - accuracy: 0.3902 - val_loss: 2.4274 - val_accuracy: 0.3216
# Epoch 6/50
# 50/50 [==============================] - 113s 2s/step - loss: 2.0048 - accuracy: 0.4150 - val_loss: 2.4160 - val_accuracy: 0.3593
# Epoch 7/50
# 50/50 [==============================] - 96s 2s/step - loss: 1.8078 - accuracy: 0.4925 - val_loss: 2.6237 - val_accuracy: 0.3229
# Epoch 8/50
# 50/50 [==============================] - 73s 1s/step - loss: 1.6706 - accuracy: 0.5300 - val_loss: 2.6779 - val_accuracy: 0.3229
# Epoch 9/50
# 50/50 [==============================] - 58s 1s/step - loss: 1.5352 - accuracy: 0.5657 - val_loss: 2.1340 - val_accuracy: 0.4083
# Epoch 10/50
# 50/50 [==============================] - 58s 1s/step - loss: 1.5063 - accuracy: 0.5738 - val_loss: 2.0787 - val_accuracy: 0.4234
# Epoch 11/50
# 50/50 [==============================] - 44s 880ms/step - loss: 1.3294 - accuracy: 0.6136 - val_loss: 2.0068 - val_accuracy: 0.4271
# Epoch 12/50
# 50/50 [==============================] - 32s 650ms/step - loss: 1.2022 - accuracy: 0.6350 - val_loss: 2.1127 - val_accuracy: 0.4133
# Epoch 13/50
# 50/50 [==============================] - 39s 771ms/step - loss: 1.1421 - accuracy: 0.6667 - val_loss: 2.0831 - val_accuracy: 0.4070
# Epoch 14/50
# 50/50 [==============================] - 27s 535ms/step - loss: 1.0346 - accuracy: 0.6888 - val_loss: 2.3249 - val_accuracy: 0.3832
# Epoch 15/50
# 50/50 [==============================] - 25s 509ms/step - loss: 0.9712 - accuracy: 0.7113 - val_loss: 2.0146 - val_accuracy: 0.4472
# Epoch 16/50
# 50/50 [==============================] - 25s 497ms/step - loss: 0.9359 - accuracy: 0.7200 - val_loss: 2.0129 - val_accuracy: 0.4598
# Epoch 17/50
# 50/50 [==============================] - 21s 425ms/step - loss: 0.8200 - accuracy: 0.7563 - val_loss: 2.0821 - val_accuracy: 0.4372
# Epoch 18/50
# 50/50 [==============================] - 18s 358ms/step - loss: 0.7624 - accuracy: 0.7626 - val_loss: 1.9230 - val_accuracy: 0.4648
# Epoch 19/50
# 50/50 [==============================] - 17s 343ms/step - loss: 0.7232 - accuracy: 0.7980 - val_loss: 2.0411 - val_accuracy: 0.4548
# Epoch 20/50
# 50/50 [==============================] - 15s 302ms/step - loss: 0.6887 - accuracy: 0.7962 - val_loss: 2.2223 - val_accuracy: 0.4435
# Epoch 21/50
# 50/50 [==============================] - 17s 344ms/step - loss: 0.7037 - accuracy: 0.7955 - val_loss: 2.6025 - val_accuracy: 0.3907
# Epoch 22/50
# 50/50 [==============================] - 15s 308ms/step - loss: 0.6169 - accuracy: 0.8250 - val_loss: 2.2092 - val_accuracy: 0.4296
# Epoch 23/50
# 50/50 [==============================] - 16s 320ms/step - loss: 0.5490 - accuracy: 0.8359 - val_loss: 2.1692 - val_accuracy: 0.4460
# Epoch 24/50
# 50/50 [==============================] - 15s 295ms/step - loss: 0.5923 - accuracy: 0.8270 - val_loss: 2.2325 - val_accuracy: 0.4485
# Epoch 25/50
# 50/50 [==============================] - 16s 316ms/step - loss: 0.4751 - accuracy: 0.8487 - val_loss: 2.0599 - val_accuracy: 0.4837
# Epoch 26/50
# 50/50 [==============================] - 16s 327ms/step - loss: 0.4520 - accuracy: 0.8712 - val_loss: 2.1418 - val_accuracy: 0.4560
# Epoch 27/50
# 50/50 [==============================] - 14s 282ms/step - loss: 0.4408 - accuracy: 0.8662 - val_loss: 2.2018 - val_accuracy: 0.4535
# Epoch 28/50
# 50/50 [==============================] - 14s 281ms/step - loss: 0.4219 - accuracy: 0.8838 - val_loss: 2.1477 - val_accuracy: 0.4749
# Epoch 29/50
# 50/50 [==============================] - 15s 291ms/step - loss: 0.4185 - accuracy: 0.8737 - val_loss: 2.0772 - val_accuracy: 0.4824
# Epoch 30/50
# 50/50 [==============================] - 14s 281ms/step - loss: 0.3449 - accuracy: 0.8850 - val_loss: 2.1999 - val_accuracy: 0.4648
# Epoch 31/50
# 50/50 [==============================] - 14s 276ms/step - loss: 0.3468 - accuracy: 0.8963 - val_loss: 2.3002 - val_accuracy: 0.4661
# Epoch 32/50
# 50/50 [==============================] - 14s 274ms/step - loss: 0.3867 - accuracy: 0.8763 - val_loss: 2.5359 - val_accuracy: 0.4422
# Epoch 33/50
# 50/50 [==============================] - 14s 289ms/step - loss: 0.3521 - accuracy: 0.8888 - val_loss: 2.3754 - val_accuracy: 0.4359
# Epoch 34/50
# 50/50 [==============================] - 14s 287ms/step - loss: 0.3021 - accuracy: 0.9050 - val_loss: 2.5144 - val_accuracy: 0.4183
# Epoch 35/50
# 50/50 [==============================] - 14s 280ms/step - loss: 0.3001 - accuracy: 0.9150 - val_loss: 2.1047 - val_accuracy: 0.4837
# Epoch 36/50
# 50/50 [==============================] - 14s 282ms/step - loss: 0.3068 - accuracy: 0.9167 - val_loss: 2.1886 - val_accuracy: 0.4510
# Epoch 37/50
# 50/50 [==============================] - 14s 276ms/step - loss: 0.3149 - accuracy: 0.9104 - val_loss: 2.2875 - val_accuracy: 0.4334
# Epoch 38/50
# 50/50 [==============================] - 14s 281ms/step - loss: 0.3023 - accuracy: 0.9050 - val_loss: 2.2898 - val_accuracy: 0.4435
# Epoch 39/50
# 50/50 [==============================] - 14s 286ms/step - loss: 0.2813 - accuracy: 0.9062 - val_loss: 2.3915 - val_accuracy: 0.4472
# Epoch 40/50
# 50/50 [==============================] - 14s 285ms/step - loss: 0.2454 - accuracy: 0.9225 - val_loss: 2.1633 - val_accuracy: 0.4686
# Epoch 41/50
# 50/50 [==============================] - 14s 286ms/step - loss: 0.2837 - accuracy: 0.9104 - val_loss: 2.2568 - val_accuracy: 0.4510
# Epoch 42/50
# 50/50 [==============================] - 14s 282ms/step - loss: 0.2414 - accuracy: 0.9200 - val_loss: 2.2901 - val_accuracy: 0.4623
# Epoch 43/50
# 50/50 [==============================] - 14s 282ms/step - loss: 0.2255 - accuracy: 0.9362 - val_loss: 2.9109 - val_accuracy: 0.3706
# Epoch 44/50
# 50/50 [==============================] - 14s 280ms/step - loss: 0.2052 - accuracy: 0.9400 - val_loss: 2.3287 - val_accuracy: 0.4585
# Epoch 45/50
# 50/50 [==============================] - 14s 282ms/step - loss: 0.2694 - accuracy: 0.9150 - val_loss: 2.6119 - val_accuracy: 0.4460
# Epoch 46/50
# 50/50 [==============================] - 14s 289ms/step - loss: 0.2359 - accuracy: 0.9325 - val_loss: 2.3839 - val_accuracy: 0.4698
# Epoch 47/50
# 50/50 [==============================] - 15s 299ms/step - loss: 0.2285 - accuracy: 0.9287 - val_loss: 2.4317 - val_accuracy: 0.4510
# Epoch 48/50
# 50/50 [==============================] - 14s 284ms/step - loss: 0.2007 - accuracy: 0.9475 - val_loss: 2.5510 - val_accuracy: 0.4334
# Epoch 49/50
# 50/50 [==============================] - 14s 285ms/step - loss: 0.2433 - accuracy: 0.9262 - val_loss: 2.5274 - val_accuracy: 0.4497
# Epoch 50/50
# 50/50 [==============================] - 14s 280ms/step - loss: 0.2294 - accuracy: 0.9237 - val_loss: 2.6065 - val_accuracy: 0.4523

# %%
history = model.fit(train_generator,
                                steps_per_epoch=50,
                                epochs=50, 
                                validation_data=validation_generator, 
                                validation_steps=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 11s 215ms/step - loss: 4.1136 - accuracy: 0.0925 - val_loss: 6.0562 - val_accuracy: 0.0942
# Epoch 2/50
# 50/50 [==============================] - 10s 201ms/step - loss: 3.2547 - accuracy: 0.2138 - val_loss: 4.0936 - val_accuracy: 0.1734
# Epoch 3/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.7827 - accuracy: 0.2862 - val_loss: 3.3363 - val_accuracy: 0.2324
# Epoch 4/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.5545 - accuracy: 0.3150 - val_loss: 3.2959 - val_accuracy: 0.2060
# Epoch 5/50
# 50/50 [==============================] - 10s 202ms/step - loss: 2.2439 - accuracy: 0.3913 - val_loss: 2.5831 - val_accuracy: 0.3103
# Epoch 6/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.0066 - accuracy: 0.4525 - val_loss: 3.0138 - val_accuracy: 0.3003
# Epoch 7/50
# 50/50 [==============================] - 10s 199ms/step - loss: 1.8408 - accuracy: 0.4737 - val_loss: 2.4201 - val_accuracy: 0.3606
# Epoch 8/50
# 50/50 [==============================] - 11s 211ms/step - loss: 1.8471 - accuracy: 0.4787 - val_loss: 2.3905 - val_accuracy: 0.3467
# Epoch 9/50
# 50/50 [==============================] - 10s 203ms/step - loss: 1.6897 - accuracy: 0.5188 - val_loss: 2.6180 - val_accuracy: 0.3153
# Epoch 10/50
# 50/50 [==============================] - 11s 212ms/step - loss: 1.5389 - accuracy: 0.5863 - val_loss: 2.4583 - val_accuracy: 0.3505
# Epoch 11/50
# 50/50 [==============================] - 11s 224ms/step - loss: 1.4159 - accuracy: 0.5833 - val_loss: 2.3485 - val_accuracy: 0.3530
# Epoch 12/50
# 50/50 [==============================] - 11s 216ms/step - loss: 1.2148 - accuracy: 0.6400 - val_loss: 2.4793 - val_accuracy: 0.3668
# Epoch 13/50
# 50/50 [==============================] - 11s 219ms/step - loss: 1.2691 - accuracy: 0.6150 - val_loss: 2.3142 - val_accuracy: 0.3882
# Epoch 14/50
# 50/50 [==============================] - 11s 217ms/step - loss: 1.2015 - accuracy: 0.6553 - val_loss: 2.4017 - val_accuracy: 0.4033
# Epoch 15/50
# 50/50 [==============================] - 11s 212ms/step - loss: 1.0717 - accuracy: 0.6975 - val_loss: 2.2479 - val_accuracy: 0.4133
# Epoch 16/50
# 50/50 [==============================] - 11s 220ms/step - loss: 0.9969 - accuracy: 0.6995 - val_loss: 2.0572 - val_accuracy: 0.4372
# Epoch 17/50
# 50/50 [==============================] - 11s 215ms/step - loss: 0.9133 - accuracy: 0.7412 - val_loss: 2.2328 - val_accuracy: 0.4108
# Epoch 18/50
# 50/50 [==============================] - 10s 210ms/step - loss: 0.9312 - accuracy: 0.7336 - val_loss: 2.1511 - val_accuracy: 0.4259
# Epoch 19/50
# 50/50 [==============================] - 10s 207ms/step - loss: 0.8152 - accuracy: 0.7563 - val_loss: 2.0006 - val_accuracy: 0.4472
# Epoch 20/50
# 50/50 [==============================] - 10s 203ms/step - loss: 0.8412 - accuracy: 0.7550 - val_loss: 2.1871 - val_accuracy: 0.4083
# Epoch 21/50
# 50/50 [==============================] - 10s 199ms/step - loss: 0.7395 - accuracy: 0.7875 - val_loss: 2.1710 - val_accuracy: 0.4171
# Epoch 22/50
# 50/50 [==============================] - 10s 201ms/step - loss: 0.7140 - accuracy: 0.7962 - val_loss: 2.1552 - val_accuracy: 0.4397
# Epoch 23/50
# 50/50 [==============================] - 10s 204ms/step - loss: 0.6311 - accuracy: 0.8238 - val_loss: 2.3051 - val_accuracy: 0.4020
# Epoch 24/50
# 50/50 [==============================] - 10s 199ms/step - loss: 0.5762 - accuracy: 0.8363 - val_loss: 2.2467 - val_accuracy: 0.4209
# Epoch 25/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.6248 - accuracy: 0.8250 - val_loss: 2.1544 - val_accuracy: 0.4523
# Epoch 26/50
# 50/50 [==============================] - 10s 201ms/step - loss: 0.5607 - accuracy: 0.8384 - val_loss: 2.3889 - val_accuracy: 0.4083
# Epoch 27/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.4935 - accuracy: 0.8687 - val_loss: 2.4693 - val_accuracy: 0.3857
# Epoch 28/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.4783 - accuracy: 0.8575 - val_loss: 2.6284 - val_accuracy: 0.3593
# Epoch 29/50
# 50/50 [==============================] - 10s 204ms/step - loss: 0.4278 - accuracy: 0.8712 - val_loss: 2.3042 - val_accuracy: 0.4422
# Epoch 30/50
# 50/50 [==============================] - 10s 201ms/step - loss: 0.4028 - accuracy: 0.8788 - val_loss: 2.5076 - val_accuracy: 0.3970
# Epoch 31/50
# 50/50 [==============================] - 10s 200ms/step - loss: 0.3908 - accuracy: 0.8813 - val_loss: 2.4304 - val_accuracy: 0.4259
# Epoch 32/50
# 50/50 [==============================] - 10s 205ms/step - loss: 0.3250 - accuracy: 0.9137 - val_loss: 2.5266 - val_accuracy: 0.4095
# Epoch 33/50
# 50/50 [==============================] - 10s 206ms/step - loss: 0.4203 - accuracy: 0.8863 - val_loss: 2.1574 - val_accuracy: 0.4460
# Epoch 34/50
# 50/50 [==============================] - 10s 204ms/step - loss: 0.3772 - accuracy: 0.8925 - val_loss: 2.3365 - val_accuracy: 0.4158
# Epoch 35/50
# 50/50 [==============================] - 10s 209ms/step - loss: 0.2909 - accuracy: 0.9125 - val_loss: 2.3998 - val_accuracy: 0.4271
# Epoch 36/50
# 50/50 [==============================] - 10s 201ms/step - loss: 0.2835 - accuracy: 0.9175 - val_loss: 2.3495 - val_accuracy: 0.4372
# Epoch 37/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.3308 - accuracy: 0.9013 - val_loss: 2.3431 - val_accuracy: 0.4372
# Epoch 38/50
# 50/50 [==============================] - 10s 201ms/step - loss: 0.2845 - accuracy: 0.9137 - val_loss: 2.5920 - val_accuracy: 0.3907
# Epoch 39/50
# 50/50 [==============================] - 10s 201ms/step - loss: 0.2881 - accuracy: 0.9100 - val_loss: 2.8626 - val_accuracy: 0.3744
# Epoch 40/50
# 50/50 [==============================] - 11s 217ms/step - loss: 0.2753 - accuracy: 0.9242 - val_loss: 2.4964 - val_accuracy: 0.4372
# Epoch 41/50
# 50/50 [==============================] - 11s 211ms/step - loss: 0.2277 - accuracy: 0.9438 - val_loss: 2.5138 - val_accuracy: 0.4435
# Epoch 42/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.1988 - accuracy: 0.9381 - val_loss: 2.6284 - val_accuracy: 0.4121
# Epoch 43/50
# 50/50 [==============================] - 10s 203ms/step - loss: 0.2855 - accuracy: 0.9137 - val_loss: 2.6499 - val_accuracy: 0.4183
# Epoch 44/50
# 50/50 [==============================] - 10s 204ms/step - loss: 0.2305 - accuracy: 0.9337 - val_loss: 2.5047 - val_accuracy: 0.4259
# Epoch 45/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.2349 - accuracy: 0.9262 - val_loss: 2.5867 - val_accuracy: 0.4322
# Epoch 46/50
# 50/50 [==============================] - 10s 203ms/step - loss: 0.2279 - accuracy: 0.9312 - val_loss: 2.5593 - val_accuracy: 0.4146
# Epoch 47/50
# 50/50 [==============================] - 10s 205ms/step - loss: 0.1901 - accuracy: 0.9362 - val_loss: 2.6210 - val_accuracy: 0.4221
# Epoch 48/50
# 50/50 [==============================] - 10s 202ms/step - loss: 0.1873 - accuracy: 0.9425 - val_loss: 2.6422 - val_accuracy: 0.4033
# Epoch 49/50
# 50/50 [==============================] - 10s 203ms/step - loss: 0.1862 - accuracy: 0.9407 - val_loss: 2.5418 - val_accuracy: 0.4347
# Epoch 50/50
# 50/50 [==============================] - 10s 206ms/step - loss: 0.1741 - accuracy: 0.9475 - val_loss: 2.8158 - val_accuracy: 0.4083

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(lr=0.05),
              metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                                steps_per_epoch=50,
                                epochs=50, 
                                validation_data=validation_generator, 
                                validation_steps=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 10s 207ms/step - loss: 7.1409 - accuracy: 0.0871 - val_loss: 13.3052 - val_accuracy: 0.0528
# Epoch 2/50
# 50/50 [==============================] - 10s 199ms/step - loss: 3.6108 - accuracy: 0.1174 - val_loss: 10.8239 - val_accuracy: 0.0503
# Epoch 3/50
# 50/50 [==============================] - 10s 203ms/step - loss: 3.5369 - accuracy: 0.1037 - val_loss: 22.2257 - val_accuracy: 0.0440
# Epoch 4/50
# 50/50 [==============================] - 10s 204ms/step - loss: 3.4110 - accuracy: 0.1462 - val_loss: 15.7228 - val_accuracy: 0.0791
# Epoch 5/50
# 50/50 [==============================] - 10s 200ms/step - loss: 3.4033 - accuracy: 0.1538 - val_loss: 5.8080 - val_accuracy: 0.1432
# Epoch 6/50
# 50/50 [==============================] - 10s 197ms/step - loss: 3.2908 - accuracy: 0.1612 - val_loss: 260.6540 - val_accuracy: 0.0302
# Epoch 7/50
# 50/50 [==============================] - 10s 198ms/step - loss: 3.0783 - accuracy: 0.2188 - val_loss: 4.6105 - val_accuracy: 0.1972
# Epoch 8/50
# 50/50 [==============================] - 10s 202ms/step - loss: 3.2795 - accuracy: 0.1755 - val_loss: 4.7574 - val_accuracy: 0.1457
# Epoch 9/50
# 50/50 [==============================] - 10s 199ms/step - loss: 3.0884 - accuracy: 0.2250 - val_loss: 9.7563 - val_accuracy: 0.1168
# Epoch 10/50
# 50/50 [==============================] - 10s 199ms/step - loss: 2.9309 - accuracy: 0.2663 - val_loss: 3.4436 - val_accuracy: 0.2563
# Epoch 11/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.8888 - accuracy: 0.2750 - val_loss: 4.0691 - val_accuracy: 0.2412
# Epoch 12/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.9085 - accuracy: 0.2912 - val_loss: 5.0115 - val_accuracy: 0.1734
# Epoch 13/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.7775 - accuracy: 0.2850 - val_loss: 3.7602 - val_accuracy: 0.2374
# Epoch 14/50
# 50/50 [==============================] - 10s 202ms/step - loss: 3.0028 - accuracy: 0.2713 - val_loss: 4.0194 - val_accuracy: 0.2060
# Epoch 15/50
# 50/50 [==============================] - 11s 212ms/step - loss: 2.6438 - accuracy: 0.3150 - val_loss: 8.3970 - val_accuracy: 0.1344
# Epoch 16/50
# 50/50 [==============================] - 10s 199ms/step - loss: 2.7434 - accuracy: 0.3485 - val_loss: 3.6629 - val_accuracy: 0.2274
# Epoch 17/50
# 50/50 [==============================] - 10s 205ms/step - loss: 2.6986 - accuracy: 0.3338 - val_loss: 3.1827 - val_accuracy: 0.3090
# Epoch 18/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.7329 - accuracy: 0.3350 - val_loss: 8.3651 - val_accuracy: 0.1734
# Epoch 19/50
# 50/50 [==============================] - 10s 199ms/step - loss: 2.6691 - accuracy: 0.3674 - val_loss: 5.0998 - val_accuracy: 0.2299
# Epoch 20/50
# 50/50 [==============================] - 10s 202ms/step - loss: 2.7972 - accuracy: 0.3475 - val_loss: 3.8067 - val_accuracy: 0.2173
# Epoch 21/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.7411 - accuracy: 0.3713 - val_loss: 4.4067 - val_accuracy: 0.2663
# Epoch 22/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.6438 - accuracy: 0.3675 - val_loss: 3.6425 - val_accuracy: 0.3191
# Epoch 23/50
# 50/50 [==============================] - 10s 204ms/step - loss: 2.6006 - accuracy: 0.3963 - val_loss: 4.0414 - val_accuracy: 0.2965
# Epoch 24/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.6242 - accuracy: 0.4062 - val_loss: 8.9540 - val_accuracy: 0.1520
# Epoch 25/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.4100 - accuracy: 0.4318 - val_loss: 4.4705 - val_accuracy: 0.3354
# Epoch 26/50
# 50/50 [==============================] - 10s 204ms/step - loss: 2.4418 - accuracy: 0.4400 - val_loss: 5.3574 - val_accuracy: 0.2651
# Epoch 27/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.4736 - accuracy: 0.4280 - val_loss: 5.4842 - val_accuracy: 0.2802
# Epoch 28/50
# 50/50 [==============================] - 10s 202ms/step - loss: 2.4408 - accuracy: 0.4500 - val_loss: 3.9650 - val_accuracy: 0.2952
# Epoch 29/50
# 50/50 [==============================] - 10s 204ms/step - loss: 2.5172 - accuracy: 0.4325 - val_loss: 3.2329 - val_accuracy: 0.3593
# Epoch 30/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.5001 - accuracy: 0.4437 - val_loss: 3.5933 - val_accuracy: 0.3618
# Epoch 31/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.3874 - accuracy: 0.4850 - val_loss: 4.3633 - val_accuracy: 0.3003
# Epoch 32/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.3274 - accuracy: 0.5013 - val_loss: 4.1206 - val_accuracy: 0.3354
# Epoch 33/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.4805 - accuracy: 0.4775 - val_loss: 3.9454 - val_accuracy: 0.3618
# Epoch 34/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.6464 - accuracy: 0.4525 - val_loss: 4.6899 - val_accuracy: 0.3204
# Epoch 35/50
# 50/50 [==============================] - 10s 203ms/step - loss: 2.2575 - accuracy: 0.4963 - val_loss: 6.1845 - val_accuracy: 0.3128
# Epoch 36/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.4790 - accuracy: 0.4762 - val_loss: 44.7688 - val_accuracy: 0.1985
# Epoch 37/50
# 50/50 [==============================] - 10s 202ms/step - loss: 2.1721 - accuracy: 0.5263 - val_loss: 3.9209 - val_accuracy: 0.4020
# Epoch 38/50
# 50/50 [==============================] - 10s 204ms/step - loss: 2.2331 - accuracy: 0.5387 - val_loss: 24.3885 - val_accuracy: 0.2864
# Epoch 39/50
# 50/50 [==============================] - 10s 197ms/step - loss: 2.2009 - accuracy: 0.5638 - val_loss: 5.9175 - val_accuracy: 0.2613
# Epoch 40/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.3699 - accuracy: 0.5088 - val_loss: 6.8121 - val_accuracy: 0.2915
# Epoch 41/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.5246 - accuracy: 0.5300 - val_loss: 7.1121 - val_accuracy: 0.3204
# Epoch 42/50
# 50/50 [==============================] - 10s 199ms/step - loss: 2.3084 - accuracy: 0.5188 - val_loss: 6.7110 - val_accuracy: 0.3631
# Epoch 43/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.3727 - accuracy: 0.5412 - val_loss: 8.3200 - val_accuracy: 0.3505
# Epoch 44/50
# 50/50 [==============================] - 10s 201ms/step - loss: 2.3472 - accuracy: 0.5290 - val_loss: 5.0134 - val_accuracy: 0.3618
# Epoch 45/50
# 50/50 [==============================] - 10s 210ms/step - loss: 2.3256 - accuracy: 0.5492 - val_loss: 7.3211 - val_accuracy: 0.3141
# Epoch 46/50
# 50/50 [==============================] - 10s 202ms/step - loss: 2.4364 - accuracy: 0.5462 - val_loss: 5.6841 - val_accuracy: 0.3304
# Epoch 47/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.0780 - accuracy: 0.5997 - val_loss: 7.5705 - val_accuracy: 0.2915
# Epoch 48/50
# 50/50 [==============================] - 10s 198ms/step - loss: 2.3235 - accuracy: 0.5663 - val_loss: 6.3985 - val_accuracy: 0.3568
# Epoch 49/50
# 50/50 [==============================] - 10s 198ms/step - loss: 2.2958 - accuracy: 0.5650 - val_loss: 8.4207 - val_accuracy: 0.3417
# Epoch 50/50
# 50/50 [==============================] - 10s 200ms/step - loss: 2.1822 - accuracy: 0.5750 - val_loss: 9.3191 - val_accuracy: 0.3693

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
from keras.applications import VGG19

conv_base = VGG19(weights='imagenet', include_top=False,
                input_shape=(192, 192, 3))


conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 192, 192, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 192, 192, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 192, 192, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 96, 96, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 96, 96, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 96, 96, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 48, 48, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 48, 48, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 48, 48, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 24, 24, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 24, 24, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 24, 24, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_base.trainable = False

# %%
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu', input_dim=6 * 6 * 512))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3)) 
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5)) 
model.add(layers.Dense(30, activation='softmax'))

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)
    

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255.)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size,
        shuffle=True)

validation_generator = test_datagen.flow_from_directory(
        validation_dir, 
        target_size=(image_size, image_size), 
        color_mode='rgb', 
        classes=None, 
        interpolation='hamming',
        class_mode='categorical', 
        batch_size=batch_size, 
        shuffle=False)

model.compile(loss='categorical_crossentropy',
              #optimizer=Adam(lr=0.001, decay=0, beta_1=0.9, beta_2=0.999),
              optimizer = 'rmsprop',
              metrics=['accuracy'])
# Out:
# Found 3640 images belonging to 30 classes.
# Found 796 images belonging to 30 classes.

# %%
history = model.fit(train_generator,
                                steps_per_epoch=50,
                                epochs=50, 
                                validation_data=validation_generator, 
                                validation_steps=50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 797s 16s/step - loss: 4.2216 - accuracy: 0.0821 - val_loss: 6.0941 - val_accuracy: 0.0905
# Epoch 2/50
# 50/50 [==============================] - 321s 6s/step - loss: 3.2566 - accuracy: 0.1838 - val_loss: 4.8215 - val_accuracy: 0.1420
# Epoch 3/50
# 50/50 [==============================] - 258s 5s/step - loss: 2.8985 - accuracy: 0.2500 - val_loss: 3.4805 - val_accuracy: 0.1972
# Epoch 4/50
# 50/50 [==============================] - 191s 4s/step - loss: 2.5619 - accuracy: 0.2962 - val_loss: 3.6591 - val_accuracy: 0.1910
# Epoch 5/50
# 50/50 [==============================] - 150s 3s/step - loss: 2.3946 - accuracy: 0.3447 - val_loss: 3.2697 - val_accuracy: 0.2362
# Epoch 6/50
# 50/50 [==============================] - 124s 2s/step - loss: 2.1880 - accuracy: 0.4025 - val_loss: 2.8815 - val_accuracy: 0.2701
# Epoch 7/50
# 50/50 [==============================] - 90s 2s/step - loss: 1.9797 - accuracy: 0.4343 - val_loss: 2.6440 - val_accuracy: 0.3015
# Epoch 8/50
# 50/50 [==============================] - 79s 2s/step - loss: 2.0186 - accuracy: 0.4387 - val_loss: 2.6001 - val_accuracy: 0.3053
# Epoch 9/50
# 50/50 [==============================] - 71s 1s/step - loss: 1.8692 - accuracy: 0.4735 - val_loss: 2.6768 - val_accuracy: 0.3040
# Epoch 10/50
# 50/50 [==============================] - 56s 1s/step - loss: 1.6326 - accuracy: 0.5263 - val_loss: 2.5843 - val_accuracy: 0.3241
# Epoch 11/50
# 50/50 [==============================] - 49s 972ms/step - loss: 1.6011 - accuracy: 0.5518 - val_loss: 3.0328 - val_accuracy: 0.2575
# Epoch 12/50
# 50/50 [==============================] - 42s 847ms/step - loss: 1.4992 - accuracy: 0.5800 - val_loss: 2.6324 - val_accuracy: 0.3116
# Epoch 13/50
# 50/50 [==============================] - 33s 653ms/step - loss: 1.4581 - accuracy: 0.5838 - val_loss: 2.5869 - val_accuracy: 0.3304
# Epoch 14/50
# 50/50 [==============================] - 33s 656ms/step - loss: 1.3803 - accuracy: 0.6000 - val_loss: 2.4496 - val_accuracy: 0.3719
# Epoch 15/50
# 50/50 [==============================] - 31s 619ms/step - loss: 1.2831 - accuracy: 0.6225 - val_loss: 2.4694 - val_accuracy: 0.3492
# Epoch 16/50
# 50/50 [==============================] - 22s 432ms/step - loss: 1.1720 - accuracy: 0.6587 - val_loss: 2.3272 - val_accuracy: 0.3656
# Epoch 17/50
# 50/50 [==============================] - 22s 441ms/step - loss: 1.2249 - accuracy: 0.6538 - val_loss: 2.3864 - val_accuracy: 0.3580
# Epoch 18/50
# 50/50 [==============================] - 21s 424ms/step - loss: 1.0039 - accuracy: 0.7038 - val_loss: 2.5001 - val_accuracy: 0.3769
# Epoch 19/50
# 50/50 [==============================] - 17s 341ms/step - loss: 0.9822 - accuracy: 0.7300 - val_loss: 2.5205 - val_accuracy: 0.3379
# Epoch 20/50
# 50/50 [==============================] - 20s 401ms/step - loss: 0.9918 - accuracy: 0.7237 - val_loss: 2.5763 - val_accuracy: 0.3920
# Epoch 21/50
# 50/50 [==============================] - 18s 360ms/step - loss: 0.9468 - accuracy: 0.7188 - val_loss: 2.5869 - val_accuracy: 0.3480
# Epoch 22/50
# 50/50 [==============================] - 17s 338ms/step - loss: 0.7833 - accuracy: 0.7850 - val_loss: 2.2979 - val_accuracy: 0.4083
# Epoch 23/50
# 50/50 [==============================] - 17s 347ms/step - loss: 0.7508 - accuracy: 0.7900 - val_loss: 2.3374 - val_accuracy: 0.4020
# Epoch 24/50
# 50/50 [==============================] - 16s 311ms/step - loss: 0.7238 - accuracy: 0.7850 - val_loss: 2.2581 - val_accuracy: 0.4284
# Epoch 25/50
# 50/50 [==============================] - 16s 320ms/step - loss: 0.7485 - accuracy: 0.7866 - val_loss: 2.3071 - val_accuracy: 0.4334
# Epoch 26/50
# 50/50 [==============================] - 16s 319ms/step - loss: 0.7319 - accuracy: 0.7875 - val_loss: 2.3120 - val_accuracy: 0.4183
# Epoch 27/50
# 50/50 [==============================] - 15s 310ms/step - loss: 0.5961 - accuracy: 0.8250 - val_loss: 2.4783 - val_accuracy: 0.3744
# Epoch 28/50
# 50/50 [==============================] - 17s 335ms/step - loss: 0.6190 - accuracy: 0.8263 - val_loss: 2.4332 - val_accuracy: 0.3920
# Epoch 29/50
# 50/50 [==============================] - 15s 306ms/step - loss: 0.6059 - accuracy: 0.8263 - val_loss: 2.3851 - val_accuracy: 0.3982
# Epoch 30/50
# 50/50 [==============================] - 16s 314ms/step - loss: 0.5599 - accuracy: 0.8200 - val_loss: 2.4227 - val_accuracy: 0.3869
# Epoch 31/50
# 50/50 [==============================] - 16s 312ms/step - loss: 0.4821 - accuracy: 0.8548 - val_loss: 2.4120 - val_accuracy: 0.4070
# Epoch 32/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.4912 - accuracy: 0.8487 - val_loss: 2.4805 - val_accuracy: 0.4133
# Epoch 33/50
# 50/50 [==============================] - 15s 302ms/step - loss: 0.4438 - accuracy: 0.8624 - val_loss: 2.4203 - val_accuracy: 0.4259
# Epoch 34/50
# 50/50 [==============================] - 15s 305ms/step - loss: 0.4360 - accuracy: 0.8825 - val_loss: 2.3434 - val_accuracy: 0.4121
# Epoch 35/50
# 50/50 [==============================] - 15s 301ms/step - loss: 0.4775 - accuracy: 0.8575 - val_loss: 2.8349 - val_accuracy: 0.3731
# Epoch 36/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.4528 - accuracy: 0.8637 - val_loss: 2.5789 - val_accuracy: 0.4045
# Epoch 37/50
# 50/50 [==============================] - 15s 305ms/step - loss: 0.3464 - accuracy: 0.9038 - val_loss: 2.6478 - val_accuracy: 0.3982
# Epoch 38/50
# 50/50 [==============================] - 15s 308ms/step - loss: 0.3091 - accuracy: 0.9137 - val_loss: 2.5202 - val_accuracy: 0.4183
# Epoch 39/50
# 50/50 [==============================] - 15s 305ms/step - loss: 0.2917 - accuracy: 0.9200 - val_loss: 2.5337 - val_accuracy: 0.3995
# Epoch 40/50
# 50/50 [==============================] - 15s 307ms/step - loss: 0.3678 - accuracy: 0.8975 - val_loss: 2.4548 - val_accuracy: 0.4095
# Epoch 41/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.3479 - accuracy: 0.8914 - val_loss: 2.4542 - val_accuracy: 0.4322
# Epoch 42/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.3247 - accuracy: 0.9100 - val_loss: 2.4539 - val_accuracy: 0.4146
# Epoch 43/50
# 50/50 [==============================] - 15s 303ms/step - loss: 0.2812 - accuracy: 0.9112 - val_loss: 2.8538 - val_accuracy: 0.3844
# Epoch 44/50
# 50/50 [==============================] - 15s 301ms/step - loss: 0.2716 - accuracy: 0.9162 - val_loss: 2.6460 - val_accuracy: 0.3970
# Epoch 45/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.2806 - accuracy: 0.9100 - val_loss: 2.7105 - val_accuracy: 0.4045
# Epoch 46/50
# 50/50 [==============================] - 15s 306ms/step - loss: 0.2438 - accuracy: 0.9255 - val_loss: 2.6479 - val_accuracy: 0.4309
# Epoch 47/50
# 50/50 [==============================] - 15s 303ms/step - loss: 0.2764 - accuracy: 0.9125 - val_loss: 2.9079 - val_accuracy: 0.3706
# Epoch 48/50
# 50/50 [==============================] - 15s 300ms/step - loss: 0.2349 - accuracy: 0.9375 - val_loss: 2.7601 - val_accuracy: 0.3920
# Epoch 49/50
# 50/50 [==============================] - 15s 303ms/step - loss: 0.2626 - accuracy: 0.9187 - val_loss: 2.9155 - val_accuracy: 0.3693
# Epoch 50/50
# 50/50 [==============================] - 15s 299ms/step - loss: 0.2137 - accuracy: 0.9369 - val_loss: 2.5720 - val_accuracy: 0.3957

# %% [markdown]
# Epoch 1/50
# 50/50 [==============================] - 778s 16s/step - loss: 3655785021.2201 - accuracy: 0.0120 - val_loss: 4.7893 - val_accuracy: 0.0330
#
# Epoch 2/50
# 50/50 [==============================] - 733s 15s/step - loss: 145.1259 - accuracy: 0.0070 - val_loss: 4.8185 - val_accuracy: 0.0000e+00
#
# Epoch 3/50
# 50/50 [==============================] - 788s 16s/step - loss: 15.5342 - accuracy: 0.0080 - val_loss: 4.7991 - val_accuracy: 0.0000e+00
#
# Epoch 4/50
# 50/50 [==============================] - 707s 14s/step - loss: 4.7877 - accuracy: 0.0050 - val_loss: 4.7963 - val_accuracy: 0.0265
#
# Epoch 5/50
# 50/50 [==============================] - 757s 15s/step - loss: 83.0197 - accuracy: 0.0110 - val_loss: 4.8147 - val_accuracy: 0.0000e+00
#
# Epoch 6/50
# 50/50 [==============================] - 793s 16s/step - loss: 5.0347 - accuracy: 0.0080 - val_loss: 4.7860 - val_accuracy: 0.0300
#
# Epoch 7/50
# 50/50 [==============================] - 814s 16s/step - loss: 4.7851 - accuracy: 0.0080 - val_loss: 4.7890 - val_accuracy: 0.0387
#
# Epoch 8/50
# 50/50 [==============================] - 786s 16s/step - loss: 4.7876 - accuracy: 0.0160 - val_loss: 4.8051 - val_accuracy: 0.0000e+00
#
# Epoch 9/50
# 50/50 [==============================] - 671s 13s/step - loss: 4.7865 - accuracy: 0.0090 - val_loss: 4.7384 - val_accuracy: 0.0000e+00
#
# Epoch 10/50
# 50/50 [==============================] - 660s 13s/step - loss: 4.7861 - accuracy: 0.0100 - val_loss: 4.8037 - val_accuracy: 0.0387
#
# Epoch 11/50
# 50/50 [==============================] - 668s 13s/step - loss: 4.7875 - accuracy: 0.0070 - val_loss: 4.8237 - val_accuracy: 0.0000e+00
#
# Epoch 12/50
# 50/50 [==============================] - 691s 14s/step - loss: 4.7853 - accuracy: 0.0100 - val_loss: 4.8210 - val_accuracy: 0.0000e+00
#
# Epoch 13/50
# 50/50 [==============================] - 661s 13s/step - loss: 4.7858 - accuracy: 0.0130 - val_loss: 4.7448 - val_accuracy: 0.0000e+00
#
# Epoch 14/50
# 50/50 [==============================] - 664s 13s/step - loss: 4.7869 - accuracy: 0.0080 - val_loss: 4.7589 - val_accuracy: 0.0000e+00
#
# Epoch 15/50
# 50/50 [==============================] - 660s 13s/step - loss: 4.7859 - accuracy: 0.0070 - val_loss: 4.7449 - val_accuracy: 0.0000e+00
#
# Epoch 16/50
# 50/50 [==============================] - 670s 13s/step - loss: 4.7834 - accuracy: 0.0090 - val_loss: 4.7287 - val_accuracy: 0.0387
#
# Epoch 17/50
# 50/50 [==============================] - 659s 13s/step - loss: 4.7820 - accuracy: 0.0080 - val_loss: 4.7361 - val_accuracy: 0.0000e+00
#
# Epoch 18/50
# 50/50 [==============================] - 669s 13s/step - loss: 4.7833 - accuracy: 0.0170 - val_loss: 4.8343 - val_accuracy: 0.0000e+00
#
# Epoch 19/50
# 50/50 [==============================] - 661s 13s/step - loss: 4.7851 - accuracy: 0.0120 - val_loss: 4.7925 - val_accuracy: 0.0000e+00
#
# Epoch 20/50
# 50/50 [==============================] - 661s 13s/step - loss: 4.7800 - accuracy: 0.0120 - val_loss: 4.8712 - val_accuracy: 0.0380
#
# Epoch 21/50
# 50/50 [==============================] - 666s 13s/step - loss: 4.7822 - accuracy: 0.0070 - val_loss: 4.8462 - val_accuracy: 0.0000e+00
#
# Epoch 22/50
# 50/50 [==============================] - 655s 13s/step - loss: 4.7848 - accuracy: 0.0110 - val_loss: 4.8039 - val_accuracy: 0.0000e+00
#
# Epoch 23/50
# 50/50 [==============================] - 651s 13s/step - loss: 4.7825 - accuracy: 0.0160 - val_loss: 4.7827 - val_accuracy: 0.0387
#
# Epoch 24/50
# 50/50 [==============================] - 657s 13s/step - loss: 4.7846 - accuracy: 0.0150 - val_loss: 4.9134 - val_accuracy: 0.0000e+00
#
# Epoch 25/50
# 50/50 [==============================] - 658s 13s/step - loss: 4.7809 - accuracy: 0.0170 - val_loss: 4.6945 - val_accuracy: 0.0000e+00
#
# Epoch 26/50
# 50/50 [==============================] - 661s 13s/step - loss: 4.7841 - accuracy: 0.0100 - val_loss: 4.6953 - val_accuracy: 0.0387
#
# Epoch 27/50
# 50/50 [==============================] - 675s 14s/step - loss: 4.7800 - accuracy: 0.0121 - val_loss: 4.8812 - val_accuracy: 0.0000e+00
#
# Epoch 28/50
# 50/50 [==============================] - 655s 13s/step - loss: 4.7864 - accuracy: 0.0100 - val_loss: 4.6395 - val_accuracy: 0.0000e+00
#
# Epoch 29/50
# 50/50 [==============================] - 653s 13s/step - loss: 4.7796 - accuracy: 0.0110 - val_loss: 4.6433 - val_accuracy: 0.0387
#
# Epoch 30/50
# 50/50 [==============================] - 653s 13s/step - loss: 4.7829 - accuracy: 0.0070 - val_loss: 4.8469 - val_accuracy: 0.0000e+00
#
# Epoch 31/50
# 50/50 [==============================] - 653s 13s/step - loss: 4.7823 - accuracy: 0.0090 - val_loss: 4.7872 - val_accuracy: 0.0000e+00
#
# Epoch 32/50
# 50/50 [==============================] - 650s 13s/step - loss: 4.7790 - accuracy: 0.0130 - val_loss: 4.7871 - val_accuracy: 0.0387
#
# Epoch 33/50
# 50/50 [==============================] - 655s 13s/step - loss: 4.7822 - accuracy: 0.0160 - val_loss: 4.7261 - val_accuracy: 0.0000e+00
#
# Epoch 34/50
# 50/50 [==============================] - 654s 13s/step - loss: 4.7810 - accuracy: 0.0120 - val_loss: 4.8707 - val_accuracy: 0.0000e+00
#
# Epoch 35/50
# 50/50 [==============================] - 650s 13s/step - loss: 4.7812 - accuracy: 0.0110 - val_loss: 4.7540 - val_accuracy: 0.0387
#
# Epoch 36/50
# 50/50 [==============================] - 654s 13s/step - loss: 4.7826 - accuracy: 0.0130 - val_loss: 4.7380 - val_accuracy: 0.0000e+00
#
# Epoch 37/50
# 50/50 [==============================] - 652s 13s/step - loss: 4.7786 - accuracy: 0.0090 - val_loss: 4.8681 - val_accuracy: 0.0000e+00
#
# Epoch 38/50
# 50/50 [==============================] - 647s 13s/step - loss: 4.7761 - accuracy: 0.0131 - val_loss: 4.4505 - val_accuracy: 0.0295
#
# Epoch 39/50
# 50/50 [==============================] - 652s 13s/step - loss: 4.7849 - accuracy: 0.0060 - val_loss: 4.6830 - val_accuracy: 0.0090
#
# Epoch 40/50
# 50/50 [==============================] - 653s 13s/step - loss: 4.7844 - accuracy: 0.0070 - val_loss: 4.8078 - val_accuracy: 0.0000e+00
#
# Epoch 41/50
# 50/50 [==============================] - 651s 13s/step - loss: 4.7808 - accuracy: 0.0120 - val_loss: 4.8588 - val_accuracy: 0.0000e+00
#
# Epoch 42/50
# 50/50 [==============================] - 647s 13s/step - loss: 4.7808 - accuracy: 0.0230 - val_loss: 4.7714 - val_accuracy: 0.0387
#
# Epoch 43/50
# 50/50 [==============================] - 651s 13s/step - loss: 4.7852 - accuracy: 0.0080 - val_loss: 4.8828 - val_accuracy: 0.0000e+00
#
# Epoch 44/50
# 50/50 [==============================] - 651s 13s/step - loss: 4.7774 - accuracy: 0.0110 - val_loss: 4.8677 - val_accuracy: 0.0000e+00
#
# Epoch 45/50
# 50/50 [==============================] - 647s 13s/step - loss: 4.7772 - accuracy: 0.0140 - val_loss: 4.5100 - val_accuracy: 0.0387
#
# Epoch 46/50
# 50/50 [==============================] - 654s 13s/step - loss: 4.7762 - accuracy: 0.0120 - val_loss: 4.9039 - val_accuracy: 0.0000e+00
#
# Epoch 47/50
# 50/50 [==============================] - 652s 13s/step - loss: 4.7797 - accuracy: 0.0120 - val_loss: 4.6210 - val_accuracy: 0.0000e+00
#
# Epoch 48/50
# 50/50 [==============================] - 649s 13s/step - loss: 4.7772 - accuracy: 0.0110 - val_loss: 4.7085 - val_accuracy: 0.0387
#
# Epoch 49/50
# 50/50 [==============================] - 652s 13s/step - loss: 4.7795 - accuracy: 0.0160 - val_loss: 4.8322 - val_accuracy: 0.0000e+00
#
# Epoch 50/50
# 50/50 [==============================] - 652s 13s/step - loss: 4.7808 - accuracy: 0.0150 - val_loss: 4.6877 - val_accuracy: 0.0000e+00

# %% [markdown]
# ![image.png](data:image/png;base64,...)
